# %% [markdown]
# 1. Calcular el tamaño de la cadena "Esta es una cadena" sin usar la función len

# %%
def string_length(str1):
    count = 0
    for char in str1:
        count += 1
    return count
print(string_length('Esta es una cadena'))
# Out:
# 18

# %% [markdown]
# 2. Implementa la función y pruébala con la cadena 'trabajando.pe', mostrando un diccionario con el número de apariciones de cada caracter.

# %%
def cont_car(cad):
    dicc = {}
    for n in cad:
        keys = dicc.keys()
        if n in keys:
            dicc[n] += 1
        else:
            dicc[n] = 1
    return dicc

# %%
cont_car('trabajando.pe')
# Out:
# {'t': 1,
#  'r': 1,
#  'a': 3,
#  'b': 1,
#  'j': 1,
#  'n': 1,
#  'd': 1,
#  'o': 1,
#  '.': 1,
#  'p': 1,
#  'e': 1}

# %% [markdown]
# 3. Eliminar duplicados de la lista ['a', 'b', 'c', 'a', 'c', 'c']

# %%
lista = ['a', 'b', 'c', 'a', 'c', 'c']

# %%
nlist = []
for i in lista:
    if i not in nlist:
        nlist.append(i)
print(nlist)
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# 4. Imprimir el patron siguiente usando bucles

# %%
pstar = [1,2,3,4,5,4,3,2,1]
for i in pstar:
    print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# 5. Escribir una función para determinar si un número es primo o no

# %% [markdown]
# Un número primo es un número natural mayor que 1 que solo tiene dos divisores: 1 y sí mismo. Es decir, no puede ser dividido exactamente por ningún otro número.
#
# Por ejemplo:
# - 2 es un número primo porque solo puede dividirse entre 1 y 2.
# - 3 es un número primo porque solo puede dividirse entre 1 y 3.
# - 4 no es un número primo porque puede dividirse entre 1, 2 y 4.

# %%
def is_prime(ent):
    if ent == 1:
        prime = True
    elif ent == 2:
        prime = True
    else:
        for num in range (2, ent):
            if ent % num == 0:
                prime = False
                break
            else:
                prime = True
    return prime

# %%
is_prime(15)
# Out:
# False
