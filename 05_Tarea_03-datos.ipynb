# %% [markdown]
# # PREGUNTA 01: crear un programa que lee un archivo de texto y retorna el numero de palabras del mismo, usar dog_breeds.txt
#
# EJEMPLO
# ```python
# with open('dog_breeds.txt', 'r') as reader:
#     ...
#
# ```
#
# OUTPUT:
# NUMERO DE PALABRAS: 26

# %% [markdown]
# # PREGUNTA 02: Análisis con Pandas
# 1. Crear o leer un archivo CSV (por ejemplo `empleados.csv`) que contenga columnas como 'nombre', 'departamento', 'edad' y 'salario'.
# 2. Cargar el CSV en un DataFrame de pandas y mostrar las primeras 5 filas.
# 3. Filtrar el DataFrame para mostrar únicamente a los empleados que pertenecen al departamento de 'Ingeniería' o 'Data'.
# 4. Calcular y mostrar por pantalla el promedio de la columna 'salario' del DataFrame filtrado.
#
# EJEMPLO
# ```python
# import pandas as pd
# ...
# df = pd.read_csv('empleados.csv')
# ...

# %% [markdown]
# # PREGUNTA 03: Convertir de JSON a CSV
# Usar la respuesta en formato JSON de la url "https://dummyjson.com/todos" y convertir a CSV únicamente los primeros 10 "todos" documentos.
#
# EJEMPLO
# ```python
# ...
# import requests
# import csv
#
# response = requests.get("https://dummyjson.com/todos")

# %% [markdown]
# # PREGUNTA 04: Serialización y manipulación con `json` y `restaurants.json`
# El objetivo es dominar la lectura, escritura y manipulación de archivos JSON utilizando un dataset de restaurantes.
#
# 1. **Lectura y Deserialización**:
#    - Carga el archivo `restaurants.json` (o una muestra del mismo) usando `json.load()`.
#    - Verifica que el contenido se haya convertido correctamente a una lista de diccionarios en Python.
# 2. **Filtrado**:
#    - Crea un nuevo archivo llamado `staten_island_restaurants.json`.
#    - Filtra los restaurantes que pertenezcan al borough "Staten Island" y guárdalos en este nuevo archivo usando `json.dump()` con `indent=4`.
# 3. **Serialización a String**:
#    - Toma el primer restaurante del dataset original, conviértelo a un string JSON usando `json.dumps()` y muestra el resultado en pantalla para inspeccionar su estructura.
# 4. **Conversión de String**:
#    - Declara un string con formato JSON que represente un nuevo restaurante con los campos `name` y `cuisine`. Usa `json.loads()` para convertirlo a un diccionario y agrégalo a tu lista de restaurantes.
#
# * **EJEMPLO:**
# ```python
# import json
#
# # Cargar el archivo
# with open('restaurants.json', 'r') as f:
#     data = json.load(f)
#
# # Tu código para filtrar y guardar aquí
