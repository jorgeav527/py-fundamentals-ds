# %% [markdown]
# # Laboratorio 10: ETL, EDA y Feature Engineering - Titanic Dataset
#
# Bienvenido a este laboratorio avanzado de análisis de datos. En esta sesión, exploraremos el legendario dataset del Titanic para entender qué factores influyeron en la supervivencia de los pasajeros. Pasaremos por un flujo completo de Ciencia de Datos: desde la extracción de datos (ETL) y el análisis exploratorio (EDA) hasta una ingeniería de características (Feature Engineering) detallada, preparando la información para futuros modelos de aprendizaje automático.

# %% [markdown]
# ## 📋 Tabla de Contenidos
#
# 1. [Configuración Inicial e Imports](#-imports)
# 2. [ETL: Extracción, Transformación y Carga](#-etl)
# 3. [EDA: Análisis Exploratorio de Datos](#-eda)
# 4. [Feature Engineering: Ingeniería de Características](#-feature-engineering)
# 5. [Preprocesamiento con Scikit-Learn](#-sklearn)

# %% [markdown]
# ---

# %% [markdown]
# <a id='-imports'></a>
# ## 🔹 1: Configuración Inicial e Imports
#
# En esta sección preparamos el entorno de trabajo importando las librerías necesarias para el manejo de datos, visualización y preprocesamiento. Configuramos los parámetros globales para garantizar gráficos consistentes y profesionales.

# %%
# #!pip install jupyter-black
# %load_ext jupyter_black

# %%
import warnings
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import pylab as plot
from sklearn.preprocessing import LabelEncoder

warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %matplotlib inline

# Configuración de visualización para Pandas
pd.options.display.max_columns = 100

# Parámetros de graficación
params = {
    "axes.labelsize": "large",
    "xtick.labelsize": "x-large",
    "legend.fontsize": 20,
    "figure.dpi": 150,
    "figure.figsize": [25, 7],
}
plot.rcParams.update(params)

# %% [markdown]
# ---

# %% [markdown]
# <a id='-etl'></a>
# ## 🔹 2: ETL (Extracción, Transformación y Carga)
#
# El primer paso consiste en cargar el conjunto de datos y realizar un diagnóstico inicial de su estructura, tipos de datos y calidad de la información (valores faltantes).

# %% [markdown]
# ### 📝 2.1 Carga de Datos
#
# Cargamos el archivo CSV que contiene los datos de entrenamiento del Titanic.

# %%
# Cargar el training set
data = pd.read_csv("train.csv")

# %% [markdown]
# ### 📝 2.2 Información Inicial del Dataset
#
# Utilizamos métodos fundamentales de Pandas para obtener una visión general de la arquitectura de los datos.

# %%
# Resumen técnico de las columnas y tipos de datos
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Muestra aleatoria para validación
print("\nMuestra aleatoria de 5 registros:")
data.sample(5)
# Out:
# Muestra aleatoria de 5 registros:
#      PassengerId  Survived  Pclass                     Name     Sex   Age  \
# 306          307         1       1  Fleming, Miss. Margaret  female   NaN
# 46            47         0       3        Lennon, Mr. Denis    male   NaN
# 278          279         0       3       Rice, Master. Eric    male   7.0
# 747          748         1       2    Sinkkonen, Miss. Anna  female  30.0
# 832          833         0       3           Saad, Mr. Amin    male   NaN
#
#      SibSp  Parch  Ticket      Fare Cabin Embarked
# 306      0      0   17421  110.8833   NaN        C
# 46       1      0  370371   15.5000   NaN        Q
# 278      4      1  382652   29.1250   NaN        Q
# 747      0      0  250648   13.0000   NaN        S
# 832      0      0    2671    7.2292   NaN        C

# %%
# Estadísticas descriptivas generales
print("\nResumen estadístico de variables numéricas:")
data.describe()
# Out:
# Resumen estadístico de variables numéricas:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ---

# %% [markdown]
# <a id='-eda'></a>
# ## 🔹 3: Análisis Exploratorio de Datos (EDA)
#
# En esta fase, generamos visualizaciones para validar hipótesis y encontrar correlaciones clave entre las variables y la supervivencia de los pasajeros.

# %% [markdown]
# ### 📝 3.1 Conteo de Sobrevivientes vs Fallecidos por Género
#
# Evaluamos la proporción de supervivencia segmentada por el género del pasajero.

# %%
# Cálculo de fallecidos
data["Died"] = 1 - data["Survived"]

# Agrupación por género y supervivencia
survival_by_gender = data.groupby("Sex").agg("sum")[["Survived", "Died"]]

survival_by_gender.columns = survival_by_gender.columns.astype(str)

# Ploteo de barras apiladas
survival_by_gender.plot(kind="bar", stacked=True, color=["g", "r"], figsize=(10, 6))

plt.title("Sobrevivientes y fallecidos por género", fontsize=16)
plt.xlabel("Género", fontsize=14)
plt.ylabel("Cantidad de Pasajeros", fontsize=14)
plt.xticks(rotation=0)
plt.legend(["Sobrevivientes", "Fallecidos"], fontsize=12)

plt.show()

# %% [markdown]
# > **Interpretación:** Las mujeres muestran una tasa de supervivencia significativamente mayor que los hombres, lo que sugiere una prioridad en el rescate basada en el género.

# %% [markdown]
# ### 📝 3.2 Distribución de Edades por Género y Supervivencia
#
# Analizamos la distribución de edad utilizando un gráfico de violín para observar la densidad de sobrevivientes por rangos etarios.

# %%
# Imputación temporal para visualización
data["Age"] = data["Age"].fillna(data["Age"].median())

plt.figure(figsize=(25, 7))
sns.violinplot(
    x="Sex",
    y="Age",
    hue="Survived",
    data=data,
    split=True,
    palette={0: "r", 1: "g"},
    linewidth=1.5,
)

plt.title("Distribución de edades por género y supervivencia", fontsize=16)
plt.xlabel("Género", fontsize=14)
plt.ylabel("Edad", fontsize=14)
plt.legend(
    title="Sobrevivencia",
    loc="upper right",
    labels=["No sobrevivió", "Sobrevivió"],
    fontsize=12,
)

plt.show()

# %% [markdown]
# > **Interpretación:** En los hombres, la edad es un factor determinante: los más jóvenes tuvieron mayor probabilidad de sobrevivir. En las mujeres, la edad no parece impactar de forma tan directa en la supervivencia.

# %% [markdown]
# ### 📝 3.3 Distribución de Tarifas por Supervivencia
#
# Determinamos si el precio del pasaje (correlacionado con el estatus social) influyó en el rescate.

# %%
fig, ax = plt.subplots(figsize=(14, 7))

# Histogramas superpuestos
ax.hist(
    data[data["Survived"] == 1]["Fare"],
    bins=50,
    color="g",
    alpha=0.7,
    label="Sobrevivieron",
)
ax.hist(
    data[data["Survived"] == 0]["Fare"],
    bins=50,
    color="r",
    alpha=0.7,
    label="Fallecieron",
)

ax.set_xlabel("Tarifa", fontsize=14)
ax.set_ylabel("Número de Pasajeros", fontsize=14)
ax.set_title("Distribución de Tarifas por Supervivencia", fontsize=16)
ax.legend(loc="upper right", fontsize=12)

plt.show()

# %% [markdown]
# > **Interpretación:** Existe una clara tendencia donde los pasajeros con tarifas más bajas tuvieron menos probabilidades de sobrevivir, evidenciando una brecha de clase en el salvamento.

# %% [markdown]
# ### 📝 3.4 Relación entre Edad, Tarifa y Supervivencia
#
# Utilizamos un gráfico de dispersión para integrar tres dimensiones de análisis y observar patrones multivariados.

# %%
plt.figure(figsize=(14, 7))
ax = plt.subplot()

ax.scatter(
    data[data["Survived"] == 1]["Age"],
    data[data["Survived"] == 1]["Fare"],
    c="green",
    s=data[data["Survived"] == 1]["Fare"],
    label="Sobrevivieron",
    alpha=0.5,
)

ax.scatter(
    data[data["Survived"] == 0]["Age"],
    data[data["Survived"] == 0]["Fare"],
    c="red",
    s=data[data["Survived"] == 0]["Fare"],
    label="Fallecieron",
    alpha=0.5,
)

ax.set_xlabel("Edad", fontsize=14)
ax.set_ylabel("Tarifa", fontsize=14)
ax.set_title("Relación entre Edad, Tarifa y Supervivencia", fontsize=16)
ax.legend()

plt.show()

# %% [markdown]
# ### 📝 3.5 Tarifa Promedio por Clase (Pclass)
#
# Confirmamos la relación entre la variable categórica Pclass y el costo del pasaje.

# %%
ax = plt.subplot()
ax.set_ylabel("Tarifa Promedio")
data.groupby("Pclass")["Fare"].mean().plot(kind="bar", figsize=(25, 7), ax=ax)
plt.title("Tarifa Promedio por Clase (Pclass)")

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <a id='-feature-engineering'></a>
# ## 🔹 4: Feature Engineering (Ingeniería de Características)
#
# En esta sección transformaremos los datos brutos en variables manejables y crearemos nuevas características basadas en el conocimiento del dominio.

# %% [markdown]
# ### 📝 4.1 Combinación de Datasets
#
# Unificamos los datos de entrenamiento y prueba para garantizar que todas las transformaciones sean uniformes y consistentes.

# %%
def get_combined_data():
    train = pd.read_csv("train.csv")
    test = pd.read_csv("test.csv")

    # Preservar targets
    targets = train.Survived
    train.drop(["Survived"], axis=1, inplace=True)

    # Combinar
    combined = pd.concat([train, test], ignore_index=True)
    combined.reset_index(inplace=True)
    combined.drop(["index", "PassengerId"], inplace=True, axis=1)

    return combined


combined = get_combined_data()
print(f"Dataset combinado creado. Dimensiones: {combined.shape}")

combined.sample(5)
# Out:
# Dataset combinado creado. Dimensiones: (1309, 10)
#       Pclass                                     Name     Sex   Age  SibSp  \
# 678        3  Goodwin, Mrs. Frederick (Augusta Tyler)  female  43.0      1
# 173        3                Sivola, Mr. Antti Wilhelm    male  21.0      0
# 288        2                     Hosono, Mr. Masabumi    male  42.0      0
# 557        1                      Robbins, Mr. Victor    male   NaN      0
# 1279       3                     Canavan, Mr. Patrick    male  21.0      0
#
#       Parch             Ticket     Fare Cabin Embarked
# 678       6            CA 2144   46.900   NaN        S
# 173       0  STON/O 2. 3101280    7.925   NaN        S
# 288       0             237798   13.000   NaN        S
# 557       0           PC 17757  227.525   NaN        C
# 1279      0             364858    7.750   NaN        Q

# %% [markdown]
# ### 📝 4.2 Procesamiento del Título
#
# Extraemos el título de los nombres de los pasajeros para clasificar su estatus social.

# %%
Title_Dictionary = {
    "Capt": "Officer",
    "Col": "Officer",
    "Major": "Officer",
    "Jonkheer": "Royalty",
    "Don": "Royalty",
    "Sir": "Royalty",
    "Dr": "Officer",
    "Rev": "Officer",
    "the Countess": "Royalty",
    "Mme": "Mrs",
    "Mlle": "Miss",
    "Ms": "Mrs",
    "Mr": "Mr",
    "Mrs": "Mrs",
    "Miss": "Miss",
    "Master": "Master",
    "Lady": "Royalty",
}


def get_titles():
    # Extracción y mapeo
    combined["Title"] = combined["Name"].map(
        lambda name: name.split(",")[1].split(".")[0].strip()
    )
    combined["Title"] = combined.Title.map(Title_Dictionary)

    return combined


combined = get_titles()
print(f"Dataset combinado creado. Dimensiones: {combined.shape}")

combined.sample(5)
# Out:
# Dataset combinado creado. Dimensiones: (1309, 11)
#      Pclass                        Name     Sex   Age  SibSp  Parch  \
# 872       1    Carlsson, Mr. Frans Olof    male  33.0      0      0
# 531       3           Toufik, Mr. Nakli    male   NaN      0      0
# 616       3   Danbom, Mr. Ernst Gilbert    male  34.0      1      1
# 641       1        Sagesser, Mlle. Emma  female  24.0      0      0
# 978       3  Badman, Miss. Emily Louisa  female  18.0      0      0
#
#         Ticket     Fare        Cabin Embarked Title
# 872        695   5.0000  B51 B53 B55        S    Mr
# 531       2641   7.2292          NaN        C    Mr
# 616     347080  14.4000          NaN        S    Mr
# 641   PC 17477  69.3000          B35        C  Miss
# 978  A/4 31416   8.0500          NaN        S  Miss

# %% [markdown]
# ### 📝 4.3 Procesamiento de Edad (Imputación por Grupos)
#
# Llenamos las edades faltantes utilizando la mediana calculada sobre grupos de Sexo, Clase y Título, evitando sesgos generales.

# %%
grouped_train = combined.iloc[:891].groupby(["Sex", "Pclass", "Title"])["Age"].median()
grouped_median_train = grouped_train.reset_index()[["Sex", "Pclass", "Title", "Age"]]


def fill_age(row):
    condition = (
        (grouped_median_train["Sex"] == row["Sex"])
        & (grouped_median_train["Title"] == row["Title"])
        & (grouped_median_train["Pclass"] == row["Pclass"])
    )
    return grouped_median_train[condition]["Age"].values[0]


def process_age():
    global combined
    combined["Age"] = combined.apply(
        lambda row: fill_age(row) if np.isnan(row["Age"]) else row["Age"], axis=1
    )
    return combined


combined = process_age()
print(f"Dataset combinado creado. Dimensiones: {combined.shape}")

combined.sample(5)
# Out:
# Dataset combinado creado. Dimensiones: (1309, 11)
#       Pclass                                      Name     Sex   Age  SibSp  \
# 971        3                      Boulos, Master. Akar    male   6.0      1
# 1264       2                    Harbeck, Mr. William H    male  44.0      0
# 1139       2  Hold, Mrs. Stephen (Annie Margaret Hill)  female  29.0      1
# 972        1                        Straus, Mr. Isidor    male  67.0      1
# 881        3                        Markun, Mr. Johann    male  33.0      0
#
#       Parch    Ticket      Fare    Cabin Embarked   Title
# 971       1      2678   15.2458      NaN        C  Master
# 1264      0    248746   13.0000      NaN        S      Mr
# 1139      0     26707   26.0000      NaN        S     Mrs
# 972       0  PC 17483  221.7792  C55 C57        S      Mr
# 881       0    349257    7.8958      NaN        S      Mr

# %% [markdown]
# ### 📝 4.4 One-Hot Encoding para Títulos
#
# Transformamos la columna categórica `Title` en variables binarias (dummies).

# %%
def process_names():
    global combined
    combined.drop("Name", axis=1, inplace=True)
    titles_dummies = pd.get_dummies(combined["Title"], prefix="Title").astype(int)
    combined = pd.concat([combined, titles_dummies], axis=1)
    combined.drop("Title", axis=1, inplace=True)
    return combined


combined = process_names()
print(f"Dataset combinado creado. Dimensiones: {combined.shape}")

combined.sample(5)
# Out:
# Dataset combinado creado. Dimensiones: (1309, 15)
#       Pclass   Sex   Age  SibSp  Parch    Ticket      Fare    Cabin Embarked  \
# 1098       2  male  24.0      0      0     28034   10.5000      NaN        S
# 350        3  male  23.0      0      0      7267    9.2250      NaN        S
# 1227       2  male  32.0      0      0    244360   13.0000      NaN        S
# 972        1  male  67.0      1      0  PC 17483  221.7792  C55 C57        S
# 1120       2  male  36.0      0      0    242963   13.0000      NaN        S
#
#       Title_Master  Title_Miss  Title_Mr  Title_Mrs  Title_Officer  \
# 1098             0           0         1          0              0
# 350              0           0         1          0              0
# 1227             0           0         1          0              0
# 972              0           0         1          0              0
# 1120             0           0         1          0              0
#
#       Title_Royalty
# 1098              0
# 350               0
# 1227              0
# 972               0
# 1120              0

# %% [markdown]
# ### 📝 4.5 Procesamiento de Tarifas, Embarque y Cabinas
#
# Realizamos imputaciones y codificaciones adicionales para las variables restantes.

# %%
def process_fares():
    global combined
    combined.Fare.fillna(combined.iloc[:891].Fare.mean(), inplace=True)
    return combined


combined = process_fares()
print(f"Dataset combinado creado. Dimensiones: {combined.shape}")

combined.sample(5)
# Out:
# Dataset combinado creado. Dimensiones: (1309, 15)
#      Pclass     Sex   Age  SibSp  Parch  Ticket      Fare Cabin Embarked  \
# 581       1  female  39.0      1      1   17421  110.8833   C68        C
# 137       1    male  37.0      1      0  113803   53.1000  C123        S
# 531       3    male  26.0      0      0    2641    7.2292   NaN        C
# 887       1  female  19.0      0      0  112053   30.0000   B42        S
# 352       3    male  15.0      1      1    2695    7.2292   NaN        C
#
#      Title_Master  Title_Miss  Title_Mr  Title_Mrs  Title_Officer  \
# 581             0           0         0          1              0
# 137             0           0         1          0              0
# 531             0           0         1          0              0
# 887             0           1         0          0              0
# 352             0           0         1          0              0
#
#      Title_Royalty
# 581              0
# 137              0
# 531              0
# 887              0
# 352              0

# %%
def process_embarked():
    global combined
    combined.Embarked.fillna("S", inplace=True)
    embarked_dummies = pd.get_dummies(combined["Embarked"], prefix="Embarked").astype(
        int
    )
    combined = pd.concat([combined, embarked_dummies], axis=1)
    combined.drop("Embarked", axis=1, inplace=True)
    return combined


combined = process_embarked()
print(f"Dataset combinado creado. Dimensiones: {combined.shape}")

combined.sample(5)
# Out:
# Dataset combinado creado. Dimensiones: (1309, 17)
#      Pclass     Sex   Age  SibSp  Parch      Ticket    Fare Cabin  \
# 66        2  female  29.0      0      0  C.A. 29395  10.500   F33
# 589       3    male  26.0      0      0  A./5. 3235   8.050   NaN
# 807       3  female  18.0      0      0      347087   7.775   NaN
# 355       3    male  28.0      0      0      345783   9.500   NaN
# 489       3    male   9.0      1      1  C.A. 37671  15.900   NaN
#
#      Title_Master  Title_Miss  Title_Mr  Title_Mrs  Title_Officer  \
# 66              0           0         0          1              0
# 589             0           0         1          0              0
# 807             0           1         0          0              0
# 355             0           0         1          0              0
# 489             1           0         0          0              0
#
#      Title_Royalty  Embarked_C  Embarked_Q  Embarked_S
# 66               0           0           0           1
# 589              0           0           0           1
# 807              0           0           0           1
# 355              0           0           0           1
# 489              0           0           0           1

# %%
def process_cabin():
    global combined
    combined.Cabin.fillna("U", inplace=True)
    combined["Cabin"] = combined["Cabin"].map(lambda c: c[0])
    cabin_dummies = pd.get_dummies(combined["Cabin"], prefix="Cabin").astype(int)
    combined = pd.concat([combined, cabin_dummies], axis=1)
    combined.drop("Cabin", axis=1, inplace=True)
    return combined


combined = process_cabin()
print(f"Dataset combinado creado. Dimensiones: {combined.shape}")

combined.sample(5)
# Out:
# Dataset combinado creado. Dimensiones: (1309, 25)
#      Pclass     Sex   Age  SibSp  Parch      Ticket     Fare  Title_Master  \
# 811       3    male  39.0      0      0   A/4 48871  24.1500             0
# 793       1    male  40.0      0      0    PC 17600  30.6958             0
# 33        2    male  66.0      0      0  C.A. 24579  10.5000             0
# 682       3    male  20.0      0      0        6563   9.2250             0
# 417       2  female  18.0      0      2      250652  13.0000             0
#
#      Title_Miss  Title_Mr  Title_Mrs  Title_Officer  Title_Royalty  \
# 811           0         1          0              0              0
# 793           0         1          0              0              0
# 33            0         1          0              0              0
# 682           0         1          0              0              0
# 417           1         0          0              0              0
#
#      Embarked_C  Embarked_Q  Embarked_S  Cabin_A  Cabin_B  Cabin_C  Cabin_D  \
# 811           0           0           1        0        0        0        0
# 793           1           0           0        0        0        0        0
# 33            0           0           1        0        0        0        0
# 682           0           0           1        0        0        0        0
# 417           0           0           1        0        0        0        0
#
#      Cabin_E  Cabin_F  Cabin_G  Cabin_T  Cabin_U
# 811        0        0        0        0        1
# 793        0        0        0        0        1
# 33         0        0        0        0        1
# 682        0        0        0        0        1
# 417        0        0        0        0        1

# %% [markdown]
# ### 📝 4.6 Procesamiento de Tickets
#
# Extraemos prefijos y manejamos los tickets numéricos puros como una categoría especial.

# %%
def cleanTicket(ticket):
    ticket = ticket.replace(".", "").replace("/", "").split()
    ticket = list(filter(lambda t: not t.isdigit(), map(lambda t: t.strip(), ticket)))
    return ticket[0] if len(ticket) > 0 else "XXX"


def process_ticket():
    global combined
    combined["Ticket"] = combined["Ticket"].map(cleanTicket)
    tickets_dummies = pd.get_dummies(combined["Ticket"], prefix="Ticket").astype(int)
    combined = pd.concat([combined, tickets_dummies], axis=1)
    combined.drop("Ticket", inplace=True, axis=1)
    return combined


combined = process_ticket()
print(f"Dataset combinado creado. Dimensiones: {combined.shape}")

combined.sample(5)
# Out:
# Dataset combinado creado. Dimensiones: (1309, 61)
#       Pclass   Sex   Age  SibSp  Parch     Fare  Title_Master  Title_Miss  \
# 864        2  male  24.0      0      0  13.0000             0           0
# 1284       2  male  47.0      0      0  10.5000             0           0
# 308        2  male  30.0      1      0  24.0000             0           0
# 361        2  male  29.0      1      0  27.7208             0           0
# 1084       2  male  61.0      0      0  12.3500             0           0
#
#       Title_Mr  Title_Mrs  Title_Officer  Title_Royalty  Embarked_C  \
# 864          1          0              0              0           0
# 1284         1          0              0              0           0
# 308          1          0              0              0           1
# 361          1          0              0              0           1
# 1084         1          0              0              0           0
#
#       Embarked_Q  Embarked_S  Cabin_A  Cabin_B  Cabin_C  Cabin_D  Cabin_E  \
# 864            0           1        0        0        0        0        0
# 1284           0           1        0        0        0        0        0
# 308            0           0        0        0        0        0        0
# 361            0           0        0        0        0        0        0
# 1084           1           0        0        0        0        0        0
#
#       Cabin_F  Cabin_G  Cabin_T  Cabin_U  Ticket_A  Ticket_A4  Ticket_A5  \
# 864         0        0        0        1         0          0          0
# 1284        0        0        0        1         0          0          0
# 308         0        0        0        1         0          0          0
# 361         0        0        0        1         0          0          0
# 1084        0        0        0        1         0          0          0
#
#       Ticket_AQ3  Ticket_AQ4  Ticket_AS  Ticket_C  Ticket_CA  Ticket_CASOTON  \
# 864            0           0          0         0          0               0
# 1284           0           0          0         0          1               0
# 308            0           0          0         0          0               0
# 361            0           0          0         0          0               0
# 1084           0           0          0         0          0               0
#
#       Ticket_FC  Ticket_FCC  Ticket_Fa  Ticket_LINE  Ticket_LP  Ticket_PC  \
# 864           0           0          0            0          0          0
# 1284          0           0          0            0          0          0
# 308           0           0          0            0          0          0
# 361           0           0          0            0          0          0
# 1084          0           0          0            0          0          0
#
#       Ticket_PP  Ticket_PPP  Ticket_SC  Ticket_SCA3  Ticket_SCA4  Ticket_SCAH  \
# 864           0           0          0            0            0            0
# 1284          0           0          0            0            0            0
# 308           0           1          0            0            0            0
# 361           0           0          0            0            0            0
# 1084          0           0          0            0            0            0
#
#       Ticket_SCOW  Ticket_SCPARIS  Ticket_SCParis  Ticket_SOC  Ticket_SOP  \
# 864             0               0               0           0           0
# 1284            0               0               0           0           0
# 308             0               0               0           0           0
# 361             0               1               0           0           0
# 1084            0               0               0           0           0
#
#       Ticket_SOPP  Ticket_SOTONO2  Ticket_SOTONOQ  Ticket_SP  Ticket_STONO  \
# 864             0               0               0          0             0
# 1284            0               0               0          0             0
# 308             0               0               0          0             0
# 361             0               0               0          0             0
# 1084            0               0               0          0             0
#
#       Ticket_STONO2  Ticket_STONOQ  Ticket_SWPP  Ticket_WC  Ticket_WEP  \
# 864               0              0            0          0           0
# 1284              0              0            0          0           0
# 308               0              0            0          0           0
# 361               0              0            0          0           0
# 1084              0              0            0          0           0
#
#       Ticket_XXX
# 864            1
# 1284           0
# 308            0
# 361            0
# 1084           1

# %% [markdown]
# ### 📝 4.7 Variables de Familia y Grupos de Edad
#
# Generamos variables que resumen el tamaño del núcleo familiar y simplifican el rango etario.

# %%
def process_family():
    global combined
    combined["FamilySize"] = combined["Parch"] + combined["SibSp"] + 1
    combined["Singleton"] = combined["FamilySize"].map(lambda s: 1 if s == 1 else 0)
    combined["SmallFamily"] = combined["FamilySize"].map(
        lambda s: 1 if 2 <= s <= 4 else 0
    )
    combined["LargeFamily"] = combined["FamilySize"].map(lambda s: 1 if 5 <= s else 0)
    return combined


combined = process_family()
print(f"Dataset combinado creado. Dimensiones: {combined.shape}")

combined.sample(5)
# Out:
# Dataset combinado creado. Dimensiones: (1309, 65)
#      Pclass     Sex   Age  SibSp  Parch      Fare  Title_Master  Title_Miss  \
# 688       3    male  18.0      0      0    7.7958             0           0
# 946       3    male  10.0      4      1   29.1250             1           0
# 434       1    male  50.0      1      0   55.9000             0           0
# 660       1    male  50.0      2      0  133.6500             0           0
# 437       2  female  24.0      2      3   18.7500             0           0
#
#      Title_Mr  Title_Mrs  Title_Officer  Title_Royalty  Embarked_C  \
# 688         1          0              0              0           0
# 946         0          0              0              0           0
# 434         1          0              0              0           0
# 660         0          0              1              0           0
# 437         0          1              0              0           0
#
#      Embarked_Q  Embarked_S  Cabin_A  Cabin_B  Cabin_C  Cabin_D  Cabin_E  \
# 688           0           1        0        0        0        0        0
# 946           1           0        0        0        0        0        0
# 434           0           1        0        0        0        0        1
# 660           0           1        0        0        0        0        0
# 437           0           1        0        0        0        0        0
#
#      Cabin_F  Cabin_G  Cabin_T  Cabin_U  Ticket_A  Ticket_A4  Ticket_A5  \
# 688        0        0        0        1         0          0          0
# 946        0        0        0        1         0          0          0
# 434        0        0        0        0         0          0          0
# 660        0        0        0        1         0          0          0
# 437        0        0        0        1         0          0          0
#
#      Ticket_AQ3  Ticket_AQ4  Ticket_AS  Ticket_C  Ticket_CA  Ticket_CASOTON  \
# 688           0           0          0         0          0               0
# 946           0           0          0         0          0               0
# 434           0           0          0         0          0               0
# 660           0           0          0         0          0               0
# 437           0           0          0         0          0               0
#
#      Ticket_FC  Ticket_FCC  Ticket_Fa  Ticket_LINE  Ticket_LP  Ticket_PC  \
# 688          0           0          0            0          0          0
# 946          0           0          0            0          0          0
# 434          0           0          0            0          0          0
# 660          0           0          0            0          0          1
# 437          0           0          0            0          0          0
#
#      Ticket_PP  Ticket_PPP  Ticket_SC  Ticket_SCA3  Ticket_SCA4  Ticket_SCAH  \
# 688          0           0          0            0            0            0
# 946          0           0          0            0            0            0
# 434          0           0          0            0            0            0
# 660          0           0          0            0            0            0
# 437          0           0          0            0            0            0
#
#      Ticket_SCOW  Ticket_SCPARIS  Ticket_SCParis  Ticket_SOC  Ticket_SOP  \
# 688            0               0               0           0           0
# 946            0               0               0           0           0
# 434            0               0               0           0           0
# 660            0               0               0           0           0
# 437            0               0               0           0           0
#
#      Ticket_SOPP  Ticket_SOTONO2  Ticket_SOTONOQ  Ticket_SP  Ticket_STONO  \
# 688            0               0               0          0             0
# 946            0               0               0          0             0
# 434            0               0               0          0             0
# 660            0               0               0          0             0
# 437            0               0               0          0             0
#
#      Ticket_STONO2  Ticket_STONOQ  Ticket_SWPP  Ticket_WC  Ticket_WEP  \
# 688              0              0            0          0           0
# 946              0              0            0          0           0
# 434              0              0            0          0           0
# 660              0              0            0          0           0
# 437              0              0            0          0           0
#
#      Ticket_XXX  FamilySize  Singleton  SmallFamily  LargeFamily
# 688           1           1          1            0            0
# 946           1           6          0            0            1
# 434           1           2          0            1            0
# 660           0           3          0            1            0
# 437           1           6          0            0            1

# %%
def process_age_groups():
    global combined
    combined["Younger"] = (combined["Age"] < 20).astype(int)
    combined["Adult"] = ((combined["Age"] >= 20) & (combined["Age"] <= 40)).astype(int)
    combined["Elder"] = (combined["Age"] > 40).astype(int)
    return combined


combined = process_age_groups()
print(f"Dataset combinado creado. Dimensiones: {combined.shape}")

combined.sample(5)
# Out:
# Dataset combinado creado. Dimensiones: (1309, 68)
#      Pclass     Sex   Age  SibSp  Parch      Fare  Title_Master  Title_Miss  \
# 848       2    male  28.0      0      1   33.0000             0           0
# 118       1    male  24.0      0      1  247.5208             0           0
# 972       1    male  67.0      1      0  221.7792             0           0
# 934       2  female  30.0      0      0   13.0000             0           0
# 932       1    male  40.0      0      0   26.5500             0           0
#
#      Title_Mr  Title_Mrs  Title_Officer  Title_Royalty  Embarked_C  \
# 848         0          0              1              0           0
# 118         1          0              0              0           1
# 972         1          0              0              0           0
# 934         0          1              0              0           0
# 932         1          0              0              0           0
#
#      Embarked_Q  Embarked_S  Cabin_A  Cabin_B  Cabin_C  Cabin_D  Cabin_E  \
# 848           0           1        0        0        0        0        0
# 118           0           0        0        1        0        0        0
# 972           0           1        0        0        1        0        0
# 934           0           1        0        0        0        0        0
# 932           0           1        0        0        0        1        0
#
#      Cabin_F  Cabin_G  Cabin_T  Cabin_U  Ticket_A  Ticket_A4  Ticket_A5  \
# 848        0        0        0        1         0          0          0
# 118        0        0        0        0         0          0          0
# 972        0        0        0        0         0          0          0
# 934        0        0        0        1         0          0          0
# 932        0        0        0        0         0          0          0
#
#      Ticket_AQ3  Ticket_AQ4  Ticket_AS  Ticket_C  Ticket_CA  Ticket_CASOTON  \
# 848           0           0          0         0          0               0
# 118           0           0          0         0          0               0
# 972           0           0          0         0          0               0
# 934           0           0          0         0          0               0
# 932           0           0          0         0          0               0
#
#      Ticket_FC  Ticket_FCC  Ticket_Fa  Ticket_LINE  Ticket_LP  Ticket_PC  \
# 848          0           0          0            0          0          0
# 118          0           0          0            0          0          1
# 972          0           0          0            0          0          1
# 934          0           0          0            0          0          0
# 932          0           0          0            0          0          0
#
#      Ticket_PP  Ticket_PPP  Ticket_SC  Ticket_SCA3  Ticket_SCA4  Ticket_SCAH  \
# 848          0           0          0            0            0            0
# 118          0           0          0            0            0            0
# 972          0           0          0            0            0            0
# 934          0           0          0            0            0            0
# 932          0           0          0            0            0            0
#
#      Ticket_SCOW  Ticket_SCPARIS  Ticket_SCParis  Ticket_SOC  Ticket_SOP  \
# 848            0               0               0           0           0
# 118            0               0               0           0           0
# 972            0               0               0           0           0
# 934            0               0               0           0           0
# 932            0               0               0           0           0
#
#      Ticket_SOPP  Ticket_SOTONO2  Ticket_SOTONOQ  Ticket_SP  Ticket_STONO  \
# 848            0               0               0          0             0
# 118            0               0               0          0             0
# 972            0               0               0          0             0
# 934            0               0               0          0             0
# 932            0               0               0          0             0
#
#      Ticket_STONO2  Ticket_STONOQ  Ticket_SWPP  Ticket_WC  Ticket_WEP  \
# 848              0              0            0          0           0
# 118              0              0            0          0           0
# 972              0              0            0          0           0
# 934              0              0            0          0           0
# 932              0              0            0          0           0
#
#      Ticket_XXX  FamilySize  Singleton  SmallFamily  LargeFamily  Younger  \
# 848           1           2          0            1            0        0
# 118           0           2          0            1            0        0
# 972           0           2          0            1            0        0
# 934           1           1          1            0            0        0
# 932           1           1          1            0            0        0
#
#      Adult  Elder
# 848      1      0
# 118      1      0
# 972      0      1
# 934      1      0
# 932      1      0

# %% [markdown]
# ---

# %% [markdown]
# <a id='-sklearn'></a>
# ## 🔹 5: Preprocesamiento con Scikit-Learn
#
# En esta sección final, aplicaremos codificación numérica profesional para las variables categóricas restantes.

# %% [markdown]
# ### 📝 5.1 Codificación de Sexo con LabelEncoder
#
# Para asegurar un flujo de datos limpio y uniforme, utilizamos `LabelEncoder` para transformar el Sexo y la Clase del Pasajero (Pclass) en valores numéricos.
#
# **Mantenimiento de Consistencia:** Siguiendo las directrices profesionales, se ha sustituido el método de dummies para Pclass por una codificación basada en Scikit-Learn.

# %%
def process_scikit_label_encoding():
    global combined
    le = LabelEncoder()
    # Codificación de Sexo
    combined["Sex"] = le.fit_transform(combined["Sex"])
    return combined


combined = process_scikit_label_encoding()
print(f"Dataset combinado creado. Dimensiones: {combined.shape}")

combined.sample(5)
# Out:
# Dataset combinado creado. Dimensiones: (1309, 68)
#       Pclass  Sex   Age  SibSp  Parch     Fare  Title_Master  Title_Miss  \
# 874        2    0  28.0      1      0  24.0000             0           0
# 102        1    1  21.0      0      1  77.2875             0           0
# 684        2    1  60.0      1      1  39.0000             0           0
# 655        2    1  24.0      2      0  73.5000             0           0
# 1250       3    0  30.0      1      0  15.5500             0           0
#
#       Title_Mr  Title_Mrs  Title_Officer  Title_Royalty  Embarked_C  \
# 874          0          1              0              0           1
# 102          1          0              0              0           0
# 684          1          0              0              0           0
# 655          1          0              0              0           0
# 1250         0          1              0              0           0
#
#       Embarked_Q  Embarked_S  Cabin_A  Cabin_B  Cabin_C  Cabin_D  Cabin_E  \
# 874            0           0        0        0        0        0        0
# 102            0           1        0        0        0        1        0
# 684            0           1        0        0        0        0        0
# 655            0           1        0        0        0        0        0
# 1250           0           1        0        0        0        0        0
#
#       Cabin_F  Cabin_G  Cabin_T  Cabin_U  Ticket_A  Ticket_A4  Ticket_A5  \
# 874         0        0        0        1         0          0          0
# 102         0        0        0        0         0          0          0
# 684         0        0        0        1         0          0          0
# 655         0        0        0        1         0          0          0
# 1250        0        0        0        1         0          0          0
#
#       Ticket_AQ3  Ticket_AQ4  Ticket_AS  Ticket_C  Ticket_CA  Ticket_CASOTON  \
# 874            0           0          0         0          0               0
# 102            0           0          0         0          0               0
# 684            0           0          0         0          0               0
# 655            0           0          0         0          0               0
# 1250           0           0          0         0          0               0
#
#       Ticket_FC  Ticket_FCC  Ticket_Fa  Ticket_LINE  Ticket_LP  Ticket_PC  \
# 874           0           0          0            0          0          0
# 102           0           0          0            0          0          0
# 684           0           0          0            0          0          0
# 655           0           0          0            0          0          0
# 1250          0           0          0            0          0          0
#
#       Ticket_PP  Ticket_PPP  Ticket_SC  Ticket_SCA3  Ticket_SCA4  Ticket_SCAH  \
# 874           0           1          0            0            0            0
# 102           0           0          0            0            0            0
# 684           0           0          0            0            0            0
# 655           0           0          0            0            0            0
# 1250          0           0          0            0            0            0
#
#       Ticket_SCOW  Ticket_SCPARIS  Ticket_SCParis  Ticket_SOC  Ticket_SOP  \
# 874             0               0               0           0           0
# 102             0               0               0           0           0
# 684             0               0               0           0           0
# 655             0               0               0           1           0
# 1250            0               0               0           0           0
#
#       Ticket_SOPP  Ticket_SOTONO2  Ticket_SOTONOQ  Ticket_SP  Ticket_STONO  \
# 874             0               0               0          0             0
# 102             0               0               0          0             0
# 684             0               0               0          0             0
# 655             0               0               0          0             0
# 1250            0               0               0          0             0
#
#       Ticket_STONO2  Ticket_STONOQ  Ticket_SWPP  Ticket_WC  Ticket_WEP  \
# 874               0              0            0          0           0
# 102               0              0            0          0           0
# 684               0              0            0          0           0
# 655               0              0            0          0           0
# 1250              0              0            0          0           0
#
#       Ticket_XXX  FamilySize  Singleton  SmallFamily  LargeFamily  Younger  \
# 874            0           2          0            1            0        0
# 102            1           2          0            1            0        0
# 684            1           3          0            1            0        0
# 655            0           3          0            1            0        0
# 1250           1           2          0            1            0        0
#
#       Adult  Elder
# 874       1      0
# 102       1      0
# 684       0      1
# 655       1      0
# 1250      1      0

# %% [markdown]
# <a id='-sklearn'></a>
# ## 🔹 6: Modeling and Prediction

# %% [markdown]
# En esta fase final, implementaremos un pipeline de aprendizaje automático para predecir la supervivencia de los pasajeros. El proceso abarca desde la preparación de los conjuntos de datos hasta la selección de las variables más influyentes y la evaluación de múltiples algoritmos para identificar el modelo con mayor capacidad predictiva.

# %% [markdown]
# ### 📝 6.1 Preparación de Herramientas y Datos
#
# Comenzamos importando los módulos necesarios de Scikit-Learn. Utilizaremos clasificadores populares, herramientas para la validación cruzada y utilidades para la selección de características.

# %%
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.feature_selection import SelectKBest, SelectFromModel
from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_val_score
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.metrics import accuracy_score
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Definimos una función para recuperar los conjuntos de entrenamiento y prueba a partir del dataframe `combined`. Es crucial separar nuevamente los datos para evitar que el modelo 'conozca' las etiquetas del conjunto de prueba durante el entrenamiento (*Data Leakage*).

# %%
def recover_train_test_target():
    global combined
    targets = pd.read_csv("train.csv", usecols=["Survived"])["Survived"].values
    train = combined.iloc[:891]
    test = combined.iloc[891:]
    return train, test, targets

# %%
train, test, targets = recover_train_test_target()

print("Train shape:", train.shape)
print("Test shape:", test.shape)
print("Targets:", len(targets))
# Out:
# Train shape: (891, 68)
# Test shape: (418, 68)
# Targets: 891

# %% [markdown]
# ### 📝 6.2 Evaluación de Relevancia (Feature Importance)
#
# El primer paso técnico es evaluar la importancia de cada característica. Utilizamos un modelo de Bosque Aleatorio (`RandomForestClassifier`) debido a su capacidad intrínseca para cuantificar cuánto contribuye cada variable a la reducción de la impureza en los nodos de decisión. Graficar la importancia nos permite visualizar qué factores (como la edad, el sexo o la tarifa) son realmente determinantes en la predicción.

# %%
# 1. Modelo Sobreajustado (Overfitted)
clf = RandomForestClassifier(
    n_estimators=100, max_depth=None, min_samples_leaf=1, random_state=42
)
clf.fit(train, targets)

features = pd.DataFrame()
features["feature"] = train.columns
features["importance"] = clf.feature_importances_
features.sort_values(by=["importance"], ascending=True, inplace=True)
features.set_index("feature", inplace=True)

plt.figure(figsize=(20, 20))
features.plot(kind="barh", figsize=(20, 20))

# línea indicando la media de importancia
mean_imp = features["importance"].mean()
plt.axvline(mean_imp, linestyle="--")
plt.title("Feature Importance (RandomForest)")
plt.show()

# %%
# 2. Modelo Regularizado
clf = RandomForestClassifier(
    n_estimators=100,
    max_depth=4,
    min_samples_leaf=5,
    max_features="sqrt",
    random_state=42,
)
clf.fit(train, targets)

features = pd.DataFrame()
features["feature"] = train.columns
features["importance"] = clf.feature_importances_
features.sort_values(by=["importance"], ascending=True, inplace=True)
features.set_index("feature", inplace=True)

plt.figure(figsize=(20, 20))
features.plot(kind="barh", figsize=(20, 20))

# línea indicando la media de importancia
mean_imp = features["importance"].mean()
plt.axvline(mean_imp, linestyle="--")
plt.title("Feature Importance (RandomForest)")
plt.show()

# %% [markdown]
# Basándonos en el análisis anterior, realizamos una reducción de dimensionalidad utilizando `SelectFromModel`. Al conservar solo aquellas características cuya importancia es superior al promedio, eliminamos el ruido y mejoramos tanto la eficiencia computacional como la capacidad de generalización del modelo.
#
# - threshold="median": Conserva el 50% de las características más importantes.
# - threshold="1.25*mean": Conserva solo variables cuya importancia supere en un 25% al promedio.
# - threshold=0.05: Conserva únicamente las variables con una importancia absoluta mayor o igual a $0.05$.

# %%
selector = SelectFromModel(clf, prefit=True, threshold="mean")

train_reduced = selector.transform(train)
test_reduced = selector.transform(test)

print("Train reduced:", train_reduced.shape)
print("Test reduced:", test_reduced.shape)
# Out:
# Train reduced: (891, 12)
# Test reduced: (418, 12)

# %% [markdown]
# ### 📝 6.3 Comparación de Modelos y Validación Cruzada
#
# Para encontrar el algoritmo más robusto, comparamos cuatro modelos distintos: Regresión Logística (estándar y con validación cruzada interna), Bosque Aleatorio y Gradient Boosting. Aplicamos validación cruzada de 5 pliegues para obtener una estimación del *accuracy* que sea estadísticamente significativa y menos dependiente de una partición específica de los datos.

# %% [markdown]
# ![Validación Cruzada](https://scikit-learn.org/stable/_images/grid_search_cross_validation.png)

# %% [markdown]
# | Métrica (`scoring`) | Pregunta Clave que responde | Ejemplo de Respuesta / Resultado |
# | :--- | :--- | :--- |
# | **`accuracy`** | ¿Qué porcentaje general de aciertos tuve? | *"El 82% de todas mis predicciones (tanto sobrevivientes como fallecidos) fueron correctas."* |
# | **`precision`** | Si predigo positivo, ¿qué tan seguro estoy de no equivocarme? | *"De 100 pasajeros que predije como sobrevivientes, 85 realmente sobrevivieron (85% de precisión)."* |
# | **`recall`** | De todos los positivos reales, ¿cuántos logré encontrar? | *"De 200 sobrevivientes reales que había en el barco, mi modelo logró identificar a 160 (80% de cobertura)."* |
# | **`f1`** | ¿Cuál es el promedio justo entre Precisión y Recall? | *"Obtuve un puntaje de 0.82, logrando un equilibrio sólido entre la precisión de predicción y la captura de reales."* |
# | **`roc_auc`** | ¿Qué tan bien separa las probabilidades de ambas clases? | *"Obtuve 0.88; el modelo tiene un 88% de probabilidad de asignar una mayor confianza de supervivencia a un sobreviviente real que a uno fallecido."* |

# %%
def compute_score(clf, X, y, scoring="accuracy"):
    xval = cross_val_score(clf, X, y, cv=5, scoring=scoring)
    return np.mean(xval)


logreg = LogisticRegression()
logreg_cv = LogisticRegressionCV()
rfc = RandomForestClassifier()
gboost = GradientBoostingClassifier()

models = [
    ("LogisticRegression", logreg),
    ("LogisticRegressionCV", logreg_cv),
    ("RandomForestClassifier", rfc),
    ("GradientBoosting", gboost),
]

results = {}

for name, model in models:
    print("Cross-validation of:", name)
    score = compute_score(model, X=train_reduced, y=targets, scoring="accuracy")
    results[name] = score
    print("CV score =", score)
    print("************")

results
# Out:
# Cross-validation of: LogisticRegression
# CV score = 0.8237900947837549
# ************
# Cross-validation of: LogisticRegressionCV
# CV score = 0.8260310087251271
# ************
# Cross-validation of: RandomForestClassifier
# CV score = 0.8125792480070304
# ************
# Cross-validation of: GradientBoosting
# CV score = 0.827154604230745
# ************
# {'LogisticRegression': np.float64(0.8237900947837549),
#  'LogisticRegressionCV': np.float64(0.8260310087251271),
#  'RandomForestClassifier': np.float64(0.8125792480070304),
#  'GradientBoosting': np.float64(0.827154604230745)}

# %% [markdown]
# Una vez obtenidos los resultados, seleccionamos el modelo con el mejor desempeño promedio. Generalmente, algoritmos de ensamble como `GradientBoostingClassifier` tienden a ofrecer resultados superiores en este tipo de datasets tabulares competitivos.

# %%
best_model = GradientBoostingClassifier()
best_model.fit(train_reduced, targets)
# Out:
# GradientBoostingClassifier()

# %% [markdown]
# ### 📝 6.4 Implementación de la Función de Predicción
#
# Encapsulamos la lógica de inferencia en una función personalizada. Esta función se encarga de transformar los datos de entrada de un nuevo pasajero al mismo formato exacto (columnas, orden y codificación) que el modelo espera, asegurando la consistencia entre el entrenamiento y la aplicación práctica.

# %%
# 1. Cargar el test.csv original solo para extraer los IDs de los pasajeros
test_original = pd.read_csv("test.csv")

# 2. Hacer la predicción con el modelo ya entrenado
predicciones = best_model.predict(test_reduced)

# 3. Crear el DataFrame final combinando los IDs originales con tus predicciones
submission = pd.DataFrame(
    {"PassengerId": test_original["PassengerId"], "Survived": predicciones}
)

# 4. Guardar el archivo listo para subir a Kaggle
submission.to_csv("submission.csv", index=False)

# %%
def predict_person(model, model_selector, **kwargs):
    """
    Recibe los datos de un pasajero (kwargs), los transforma al mismo
    formato que el dataframe 'train' y aplica el modelo.
    """
    global combined

    # convertir a DataFrame temporal
    df = pd.DataFrame([kwargs])

    # asegurar que existan todas las columnas del training
    for col in train.columns:
        if col not in df.columns:
            df[col] = 0

    # reordenar columnas para que coincidan con el training
    df = df[train.columns]

    # reducir features con el mismo selector usado en train
    df_reduced = model_selector.transform(df)

    # predecir
    prediction = model.predict(df_reduced)[0]
    return prediction

# %% [markdown]
# Probamos nuestro sistema con un caso hipotético para validar que el pipeline completo, desde el preprocesamiento de las variables hasta la decisión del modelo, funciona correctamente.

# %%
jorge = predict_person(
    model=best_model,
    model_selector=selector,
    Pclass=2,
    Sex_male=1,
    Sex_female=0,
    Age=35,
    SibSp=0,
    Parch=0,
    Fare=20,
    Embarked_S=1,
    Embarked_C=0,
    Embarked_Q=0,
    Title_Mr=1,
)

print("¿Jorge sobreviviría?:", "Sí" if jorge == 1 else "No")
# Out:
# ¿Jorge sobreviviría?: Sí
