# %% [markdown]
# # PREGUNTA 01: crear un programa que lee un archivo de texto y retorna el numero de palabras del mismo, usar dog_breeds.txt
#
# EJEMPLO
# ```python
# with open('dog_breeds.txt', 'r') as reader:
#     ...
#
# ```
#
# OUTPUT:
# NUMERO DE PALABRAS: 26

# %% [markdown]
# # PREGUNTA 02: Usando sqlalchemy o SQLModel y sqlite3 hacer lo siguiente:
# 1. usar sqlite en memoria (crear la base de datos)
# 2. crear una tabla empleado con datos personales con el siguiente esquema minimo (nombre, apellidos, edad, DNI)
# 3. insertar 10 datos aleatorios o inventados
# 4. hacer las siguientes queries
#     - Mostrar todas las filas de la tabla empleados
#     - Mostrar todos los que son mayores de 50 años
#
# EJEMPLO
# ```python
# ...
# class Empleado(Base):
#     __tablename__ = 'empleados'
#     ...
# ```
#
# OUTPUT:
# - Mostrar todas las filas de la tabla empleados
# ```SQL
# Julio Perez 51 56773221
# Carmen Maura 30 46173220
# Pedro Fuentes 28 66662211
# ...
# ```
# - Mostrar todos los que son mayores de 50 años
# ```SQL
# Julio Perez 51 56773221
# ...
# ```

# %% [markdown]
# # PREGUNTA 03: Convertir de JSON a CSV, Usar la respuesta en formato json de la url "https://jsonplaceholder.typicode.com/todos" solo los 50 primeros documentos
#
# EJEMPLO
# ```python
# ...
# import requests
# response = requests.get("https://jsonplaceholder.typicode.com/todos")
# ...
# ```
#
# OUTPUT:
# NUMERO DE DOCUMENTOS: 50

# %% [markdown]
# # PREGUNTA 04: Usando MongoDB y pymongo hacer lo siguiente:
# 1. Conectar con mongodb de manera local "mongodb://localhost:27017"
# 2. Usando mongo compass o scrips de python insertar el archivo "restaurants.json"
# 3. escribir un query que muestre solamente los campos Id, name, borough y cuisine para aquellos restaurantes ubicados en el borough Staten Island o Queens y mostrarlos en pantalla
#
# ```python
# ...
# documents = restaurantes.find(...);
# ...
# for doc in documents:
#     print(doc)
# ```
# OUTPUT:
# ```json
# {
#   "_id": {
#     "$oid": "67e34c75dbd504494b4420ae"
#   },
#   "borough": "Queens",
#   "cuisine": "Jewish/Kosher",
#   "name": "Tov Kosher Kitchen",
#   "restaurant_id": "40356068"
# }
# ...
# ```
