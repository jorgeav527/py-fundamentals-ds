# %% [markdown]
# # PREGUNTA 01:  MAP con LISTA
#
# Dada la siguiente lista de temperaturas en grados Celsius:
#
# temperaturas = [18, 21, 25, 30, 16, 22]
#
# Convertir todas las temperaturas a **Fahrenheit** usando la fórmula:
#
# F = (C * 9/5) + 32
#
# Debes resolver este problema de las siguientes 4 formas:
#
# 1. Usando un `for loop` tradicional
# - Crea una lista vacía
# - Recorre la lista original
# - Agrega los resultados transformados
#
# 2. Usando `map()` con una función normal
# - Declara una función llamada `celsius_a_fahrenheit()`
#
# 3. Usando `map()` con `lambda`
#
# 4. Usando `list comprehension`
#
# (Guíese según la explicación desarrollada en clase)

# %% [markdown]
# # PREGUNTA 02: FILTRO con TUPLA
#
# Dada la siguiente tupla de edades:
#
# edades = (12, 17, 19, 21, 15, 30, 16, 40)
#
# Filtrar únicamente las edades que sean **mayores o iguales a 18**.
#
# Debes resolver este problema de las siguientes 4 formas:
#
# 1. Usando un `for loop` tradicional
# - Crea una lista vacía
# - Recorre la tupla
# - Agrega solo las edades que cumplan la condición
#
# 2. Usando `filter()` con una función normal
# - Declara una función llamada `es_mayor_edad()`
#
# 3. Usando `filter()` con `lambda`
#
# 4. Usando `list comprehension`
#
# (Guíese según la explicación desarrollada en clase)
