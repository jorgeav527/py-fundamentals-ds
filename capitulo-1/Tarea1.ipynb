# %% [markdown]
# ### PREGUNTA 01: Calcular el tamaño de la cadena "Esta es una cadena" sin usar la función len()
#
# EJEMPLO
#
# ```python
# sample_string = 'Esta es una cadena'
# calculate_string_length(sample_string)
# OUTPUT: 18
# ```

# %% [markdown]
# ### PREGUNTA 02: Contar el numero de caracteres en la cadena trabajando.pe
#
# EJEMPLO
# ```python
# contar('trabajando.pe')
# OUTPUT: {'t': 1,
#  'r': 1,
#  'a': 3,
#  'b': 1,
#  'j': 1,
#  'n': 1,
#  'd': 1,
#  'o': 1,
#  '.': 1,
#  'p': 1,
#  'e': 1}
# ```

# %% [markdown]
# ### PREGUNTA 03: Eliminar duplicados de la lista ['a', 'b', 'c', 'a', 'c', 'c']
#
# EJEMPLO
# ```python
# lista = ['a', 'b', 'c', 'a', 'c', 'c']
# OUTPUT: ['a', 'b', 'c']
# ```

# %% [markdown]
# ### PREGUNTA 04: Imprimir el patron siguiente usando bucles
#
# OUTPUT:
# ```html
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
# ```

# %% [markdown]
# ### PREGUNTA 05. Escribir una función para determinar si un número es primo o no
#
# EJEMPLO
# ```python
# is_prime(15)
# OUTPUT: False
# ```
