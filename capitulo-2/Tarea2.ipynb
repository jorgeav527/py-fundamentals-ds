# %% [markdown]
# # PREGUNTA 01: Crear una clase Círculo que calcule área y perímetro dado un radio
# # EJEMPLO
#
# ```python
# class Circulo:
#     def __init__(self, radio):
#     ...
#
# OUTPUT:
# Área: 78.54
# Perímetro: 31.42
# ```

# %% [markdown]
# # PREGUNTA 02: Manejo de ZeroDivisionError en divisiones
# # EJEMPLO
#
# ```python
# def divzero(num, den):
#     ...
#
# OUTPUT:
# División exitosa: 5.0
# Error: No se puede dividir entre cero
# ```

# %% [markdown]
# # PREGUNTA 03: Determinar si un número es primo usando list comprehension
# # EJEMPLO
#
# ```python
# def isprime(x):
#     ...
#
# OUTPUT
# True
# False
# ```

# %% [markdown]
# # PREGUNTA 04: Crea una clase Employee crea instancias y ordenar los empleados por edad usando lambda
# ## EJEMPLO
#
# ```python
# class Employee:
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
# OUTPUT:
# ['David', 'Alex', 'Amanda']
# ```

# %% [markdown]
# # PREGUNTA 05: Decoradores para formatear texto
# ## EJEMPLO
#
# ```python
# # Definición de decoradores
#
# # Función a decorar
# @make_bold
# @make_italic
# @make_underline
# def hello():
#     return "hello world"
#
# OUTPUT:
# <b><i><u>hello world</u></i></b>
# ```
