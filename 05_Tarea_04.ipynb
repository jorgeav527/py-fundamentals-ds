# %% [markdown]
# # PREGUNTA 01: ETL - Carga y Transformación de Datos
#
# Usando `TransformData/movies_1000.csv`, realiza un proceso ETL completo:
#
# 1. **Extract**: Carga el archivo CSV en un DataFrame con `pandas`.
# 2. **Transform**:
#    - Reemplaza los valores `'\\N'` por `NaN` en las columnas `Año` y `Género`.
#    - Convierte la columna `Año` a tipo numérico (`float`).
#    - Filtra solo las películas con `Año >= 2000` y que tengan un `Rating (pro)` no nulo.
#    - Crea una nueva columna llamada `Categoría_Rating` que clasifique:
#      - `'Bajo'` si `Rating (pro) < 5.0`
#      - `'Medio'` si `5.0 <= Rating (pro) < 7.0`
#      - `'Alto'` si `Rating (pro) >= 7.0`
# 3. **Load**: Guarda el DataFrame resultante en `TransformData/peliculas_transformadas.csv` sin índice.
#
# Muestra el DataFrame final con `head()`.

# %% [markdown]
# # PREGUNTA 02: Consultas SQL a Data Warehouse
#
# Usando la base de datos `warehouse.db` (tabla `ticket_sales`) y `sqlite3` + `pandas`, realiza las siguientes consultas:
#
# 1. **Total de visitantes por formato**: Cuenta cuántos boletos se vendieron en formato `'3D'` y `'Normal'`.
# 2. **Precio promedio por género**: Calcula el precio promedio pagado por género (`M` y `F`).
# 3. **Top 5 películas por recaudación total**: Agrupa por `pelicula`, suma el `precio` total, ordena descendente y muestra las 5 primeras.
#
# Cada consulta debe ejecutarse con `pd.read_sql()` y mostrar el resultado.

# %% [markdown]
# # PREGUNTA 03: Visualización de Datos
#
# Usando `CleanData/master_data_final.csv` y las librerías `matplotlib` y `seaborn`, crea los siguientes gráficos:
#
# 1. **Barras**: Un gráfico de barras que muestre la cantidad de visitantes por género (`genero`). Usa `seaborn.barplot`.
# 2. **Pie**: Un gráfico de pastel que muestre la distribución de formatos (`formato`). Usa `matplotlib.pyplot.pie`.
# 3. **Histograma**: Un histograma de la columna `precio` para ver la distribución de precios de los boletos. Usa `matplotlib.pyplot.hist`.
#
# Todos los gráficos deben tener título y etiquetas adecuadas.
